# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import PIL.Image
import numpy as np

# Sample text related to Sidhu Moosewala
sidhu_text = """
Sidhu Moosewala is a prominent Punjabi singer, songwriter, and actor known for his impactful lyrics and unique musical style. 
He gained immense popularity with songs like 'So High', 'Issa Jatt', and 'Dollar', which often reflect themes of love, loss, and life in Punjab.
His contributions to Punjabi music have made him an influential figure in the industry.
"""

# Load Sidhu Moosewala image as a mask
sidhu_mask = np.array(PIL.Image.open('sidhu_moosewala.jpg'))

# Create the word cloud
wc = WordCloud(stopwords=STOPWORDS,
               mask=sidhu_mask,
               background_color="red",
               contour_color="red",
               contour_width=6).generate(sidhu_text)

# Display the word cloud
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
